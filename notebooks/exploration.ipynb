# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/filtered_labels.csv")
plt.hist(df["age"], bins=20, edgecolor="black")
plt.xlabel("Dob")
plt.ylabel("Broj uzoraka")
plt.title("Distribucija dobi u datasetu")
plt.show()
